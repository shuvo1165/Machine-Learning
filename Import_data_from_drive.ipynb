# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo1165/Machine-Learning/blob/main/Import_data_from_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle datasets download -d badhon7432/paddyleafdiseaseuci
# Out:
# ...
#  98% 158M/161M [00:06<00:00, 23.7MB/s]
# 100% 161M/161M [00:06<00:00, 25.9MB/s]

# %%
# !ls
# Out:
# kaggle.json  paddyleafdiseaseuci.zip

# %%
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  paddyleafdiseaseuci.zip
#   inflating: test/Bacterial leaf blight/DSC_0365.JPG
#   inflating: test/Bacterial leaf blight/DSC_0372.JPG
#   inflating: test/Bacterial leaf blight/DSC_0383.JPG
#   inflating: test/Bacterial leaf blight/DSC_0403.JPG
#   inflating: test/Bacterial leaf blight/DSC_0406.JPG
#   inflating: test/Bacterial leaf blight/blight-_0_1602.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_1905.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_1988.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2019.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2094.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2316.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2441.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2659.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_2829.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_3103.jpg
#   inflating: test/Bacterial leaf blight/blight-_0_3237.jpg
# ...

# %%
# %ls
# Out:
# kaggle.json  test/  train/  valid/

# %%
import pandas as pd

# %%
X_train = '/content/gdrive/My Drive/Kaggle/train'
X_test = '/content/gdrive/My Drive/Kaggle/test'

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('/content/gdrive/My Drive/Kaggle/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
test_set = test_datagen.flow_from_directory('/content/gdrive/My Drive/Kaggle/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 911 images belonging to 3 classes.
# Found 164 images belonging to 3 classes.

# %%
training_set
